# %% [markdown]
# # 회귀 분석이란 무엇인가요?
#
# 회귀 분석은 종속 변수('결과 변수' 또는 '대상'이라고도 함)와 하나 이상의 독립 변수('특징', '예측자' 또는 '공변량'이라고도 함) 간의 관계를
# 추정하기 위한 일련의 통계 프로세스입니다.
# 머신 러닝에서 회귀의 목적은 판매 금액, 수량, 온도 등과 같은 연속적인 값을 예측하는 것입니다.

# %% [markdown]
# # 파이캐럿 처리 방법
#
# ### - 1. 데이터 가져오기: PyCaret 저장소에서 데이터를 가져오는 방법
# ### - 2. 환경 설정하기: PyCaret에서 실험을 설정하고 회귀 모델 구축을 시작하는 방법
# ### - 3. 모델 생성: 모델 생성: 모델을 생성하고, 교차 검증을 수행하고, 회귀 메트릭을 평가하는 방법
# ### - 4. 모델 조정: 회귀 모델의 하이퍼 파라미터를 자동으로 조정하는 방법
# ### - 5. 모델 플롯: 다양한 플롯을 사용하여 모델 성능을 분석하는 방법
# ### - 6. 모델 마무리: 실험이 끝날 때 최적의 모델을 확정하는 방법
# ### - 7. 모델 예측: 새로운 데이터/보이지 않는 데이터를 예측하는 방법
# ### - 8. 모델 저장/로드: 나중에 사용하기 위해 모델을 저장/로드하는 방법

# %% [markdown]
# ## 1. 데이터 가져오기: PyCaret 저장소에서 데이터를 가져오는 방법

# %% [markdown]
# ## 파이케럿의 데이터셋 패키지의 get_data 함수를 사용

# %%
from pycaret.datasets import get_data

# %% [markdown]
# ## 모든 데이터를 확인

# %%
all_datasets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection              None              None
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit              None
# 4       Classification (Binary)             Class              None
# 5       Classification (Binary)             Class              None
# 6       Classification (Binary)           default              None
# 7       Classification (Binary)    Class variable              None
# 8       Classification (Binary)             stabf              None
# 9       Classification (Binary)              left              None
# 10      Classification (Binary)             DEATH              None
# 11      Classification (Binary)           Disease              None
# 12      Classification (Binary)             Class              None
# 13      Classification (Binary)       income >50K              None
# 14      Classification (Binary)          Purchase              None
# 15      Classification (Binary)       TARGET_5Yrs              None
# 16      Classification (Binary)              type              None
# 17      Classification (Binary)             Class              None
# 18      Classification (Binary)          Survived              None
# 19      Classification (Binary)      party_winner              None
# 20  Classification (Multiclass)              Type              None
# 21  Classification (Multiclass)           species              None
# 22  Classification (Multiclass)             CLASS              None
# 23  Classification (Multiclass)     Next_Question              None
# 24  Classification (Multiclass)             Class              None
# 25  Classification (Multiclass)               NSP              None
# 26                   Clustering              None              None
# 27                   Clustering              None              None
# 28                   Clustering              None              None
# 29                   Clustering              None              None
# 30                   Clustering              None              None
# 31                   Clustering              None              None
# 32                   Clustering              None              None
# 33                   Clustering              None              None
# 34                   Clustering              None              None
# 35                   Clustering              None              None
# 36                   Clustering              None              None
# 37                   Clustering              None              None
# 38                   Clustering              None              None
# 39                          NLP             tweet              None
# 40         NLP / Classification        reviewText              None
# 41         NLP / Classification                en              None
# 42             NLP / Regression              text              None
# 43         NLP / Classification              Text              None
# 44                   Regression             price              None
# 45                   Regression               cnt              None
# 46                   Regression              medv              None
# 47                   Regression          strength              None
# 48                   Regression             Price              None
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area              None
# 51                   Regression         Gold_T+22              None
# 52                   Regression         SalePrice              None
# 53                   Regression           charges              None
# 54                   Regression               PPE              None
# 55                   Regression    traffic_volume              None
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %% [markdown]
# ## 다이아몬드 관련 데이터만 가져온다

# %%
dataset = get_data('diamond')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %% [markdown]
# ## 데이터의 상태를 확인한다.

# %%
#check the shape of data
dataset.shape
# Out:
# (6000, 8)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Carat Weight  6000 non-null   float64
#  1   Cut           6000 non-null   object
#  2   Color         6000 non-null   object
#  3   Clarity       6000 non-null   object
#  4   Polish        6000 non-null   object
#  5   Symmetry      6000 non-null   object
#  6   Report        6000 non-null   object
#  7   Price         6000 non-null   int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 375.1+ KB

# %% [markdown]
# ## 데이터셋을 훈련과 테스트를 위해서 분리

# %%
dataset.sample(frac=0.9, random_state=786).shape
# Out:
# (5400, 8)

# %%
dataset.sample(frac=0.9, random_state=786).reset_index()
# Out:
#       index  Carat Weight        Cut Color Clarity Polish Symmetry Report  \
# 0      5333          1.50       Good     E     VS2     VG        G    GIA
# 1      3749          1.08      Ideal     D     VS2     EX       EX    GIA
# 2      2376          2.25       Good     I     VS2      G       VG    GIA
# 3      3756          2.27  Very Good     G     VS2     VG       VG    GIA
# 4      4248          1.20      Ideal     F     VS1     EX       EX    GIA
# ...     ...           ...        ...   ...     ...    ...      ...    ...
# 5395   1248          0.80      Ideal     E     VS1     VG       VG    GIA
# 5396   5299          1.02  Very Good     E     SI1     VG       EX    GIA
# 5397   4979          1.03      Ideal     F     VS2     VG       VG    GIA
# 5398    933          2.01       Good     H     VS1     VG       VG    GIA
# 5399   1653          2.01  Very Good     H     VS2     VG        G    GIA
#
#       Price
# 0     12702
# 1      8481
# 2     18623
# 3     27252
# 4      9641
# ...     ...
# 5395   3714
# 5396   5424
# 5397   6997
# 5398  18988
# 5399  19044
#
# [5400 rows x 9 columns]

# %%
dataset.sample(frac=0.9, random_state=786).reset_index(drop=True)
# Out:
#       Carat Weight        Cut Color Clarity Polish Symmetry Report  Price
# 0             1.50       Good     E     VS2     VG        G    GIA  12702
# 1             1.08      Ideal     D     VS2     EX       EX    GIA   8481
# 2             2.25       Good     I     VS2      G       VG    GIA  18623
# 3             2.27  Very Good     G     VS2     VG       VG    GIA  27252
# 4             1.20      Ideal     F     VS1     EX       EX    GIA   9641
# ...            ...        ...   ...     ...    ...      ...    ...    ...
# 5395          0.80      Ideal     E     VS1     VG       VG    GIA   3714
# 5396          1.02  Very Good     E     SI1     VG       EX    GIA   5424
# 5397          1.03      Ideal     F     VS2     VG       VG    GIA   6997
# 5398          2.01       Good     H     VS1     VG       VG    GIA  18988
# 5399          2.01  Very Good     H     VS2     VG        G    GIA  19044
#
# [5400 rows x 8 columns]

# %%
data = dataset.sample(frac=0.9, random_state=786)

# %%
data.head()
# Out:
#       Carat Weight        Cut Color Clarity Polish Symmetry Report  Price
# 5333          1.50       Good     E     VS2     VG        G    GIA  12702
# 3749          1.08      Ideal     D     VS2     EX       EX    GIA   8481
# 2376          2.25       Good     I     VS2      G       VG    GIA  18623
# 3756          2.27  Very Good     G     VS2     VG       VG    GIA  27252
# 4248          1.20      Ideal     F     VS1     EX       EX    GIA   9641

# %% [markdown]
# ## 테스트 데이터를 만듬

# %%
data_unseen = dataset.drop(data.index)

# %%
data_unseen.head()
# Out:
#     Carat Weight        Cut Color Clarity Polish Symmetry Report  Price
# 5           1.53      Ideal     E     SI1     ID       ID   AGSL  12791
# 7           1.50       Fair     F     SI1     VG       VG    GIA  10450
# 11          1.01       Good     E     SI1      G        G    GIA   5161
# 13          2.51  Very Good     G     VS2     VG       VG    GIA  34361
# 18          1.01       Good     I     SI1     VG       VG    GIA   4238

# %%
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (5400, 8)
# Unseen Data For Predictions: (600, 8)

# %% [markdown]
# ##  2. 환경 설정하기: PyCaret에서 실험을 설정하고 회귀 모델 구축을 시작하는 방법

# %% [markdown]
# ## 회귀분석 알고리즘 모듈 사용하기

# %%
from pycaret.regression import *

# %% [markdown]
# ## setup 매개변수
#
# - session_id: 추후 재현성을 위해 모든 함수에 시드로 배포되는 시드 난수입니다. 세션_id를 전달하지 않으면 자동으로 난수가 생성되어 모든 함수에 배포됩니다. 이 실험에서는 추후 재현성을 위해 세션_id를 123으로 설정했습니다.
#
# - 원본 데이터 : 데이터 세트의 원래 모양을 표시합니다. 이 실험에서 (5400, 8)은 대상 열을 포함한 5400개의 샘플과 8개의 특징을 의미합니다.
#
# 누락된 값 : 원본 데이터에 누락된 값이 있는 경우 True로 표시됩니다. 이 실험에서는 데이터 집합에 결측값이 없습니다.
#
# - 숫자 특징 : 숫자로 추론된 특징의 수입니다. 이 데이터 세트에서는 8개 특징 중 1개가 숫자로 추론됩니다.
#
# - 범주형 특징 : 범주로 추론된 특징의 개수입니다. 이 데이터셋에서는 8개 특징 중 6개가 범주형으로 추론됩니다.
#
# - 변환된 훈련 세트 : 변환된 훈련 세트의 모양을 표시합니다. 변형된 훈련 집합의 경우 (5400, 8)의 원래 모양이 (3779, 28)로 변형된 것을 확인할 수 있습니다. 범주형 인코딩으로 인해 특징의 수가 28개에서 8개로 증가했습니다.
#
# - 변환된 테스트 세트: 변환된 테스트/홀드아웃 세트의 모양을 표시합니다. 테스트/홀드아웃 세트에는 1621개의 샘플이 있습니다. 이 분할은 기본값인 70/30을 기준으로 하며, 설정에서 train_size 파라미터를 사용하여 변경할 수 있습니다.

# %% [markdown]
# ## 데이터 세트를 설정하기

# %%
exp_reg101 = setup(data = data, target = 'Price', session_id=123)
# Out:
# <style type="text/css">
# #T_4c939_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4c939">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c939_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4c939_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c939_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c939_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4c939_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c939_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4c939_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4c939_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4c939_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4c939_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4c939_row3_col1" class="data row3 col1" >(5400, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4c939_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4c939_row4_col1" class="data row4 col1" >(5400, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4c939_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4c939_row5_col1" class="data row5 col1" >(3779, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4c939_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4c939_row6_col1" class="data row6 col1" >(1621, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4c939_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_4c939_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4c939_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_4c939_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4c939_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_4c939_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4c939_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_4c939_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4c939_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_4c939_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4c939_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_4c939_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4c939_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_4c939_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4c939_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_4c939_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4c939_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_4c939_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4c939_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_4c939_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4c939_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_4c939_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4c939_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_4c939_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4c939_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_4c939_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4c939_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_4c939_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4c939_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_4c939_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4c939_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_4c939_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_4c939_row22_col1" class="data row22 col1" >a2b4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##  3. 모델 생성: 모델 생성: 모델을 생성하고, 교차 검증을 수행하고, 회귀 메트릭을 평가하는 방법

# %% [markdown]
# ## 회귀모델 비교하기

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_3a944 th {
#   text-align: left;
# }
# #T_3a944_row0_col0, #T_3a944_row1_col0, #T_3a944_row1_col1, #T_3a944_row1_col2, #T_3a944_row1_col3, #T_3a944_row1_col4, #T_3a944_row1_col5, #T_3a944_row1_col6, #T_3a944_row2_col0, #T_3a944_row2_col1, #T_3a944_row2_col2, #T_3a944_row2_col3, #T_3a944_row2_col4, #T_3a944_row2_col5, #T_3a944_row2_col6, #T_3a944_row3_col0, #T_3a944_row3_col1, #T_3a944_row3_col2, #T_3a944_row3_col3, #T_3a944_row3_col4, #T_3a944_row3_col5, #T_3a944_row3_col6, #T_3a944_row4_col0, #T_3a944_row4_col1, #T_3a944_row4_col2, #T_3a944_row4_col3, #T_3a944_row4_col4, #T_3a944_row4_col5, #T_3a944_row4_col6, #T_3a944_row5_col0, #T_3a944_row5_col1, #T_3a944_row5_col2, #T_3a944_row5_col3, #T_3a944_row5_col4, #T_3a944_row5_col5, #T_3a944_row5_col6, #T_3a944_row6_col0, #T_3a944_row6_col1, #T_3a944_row6_col2, #T_3a944_row6_col3, #T_3a944_row6_col4, #T_3a944_row6_col5, #T_3a944_row6_col6, #T_3a944_row7_col0, #T_3a944_row7_col1, #T_3a944_row7_col2, #T_3a944_row7_col3, #T_3a944_row7_col4, #T_3a944_row7_col5, #T_3a944_row7_col6, #T_3a944_row8_col0, #T_3a944_row8_col1, #T_3a944_row8_col2, #T_3a944_row8_col3, #T_3a944_row8_col4, #T_3a944_row8_col5, #T_3a944_row8_col6, #T_3a944_row9_col0, #T_3a944_row9_col1, #T_3a944_row9_col2, #T_3a944_row9_col3, #T_3a944_row9_col4, #T_3a944_row9_col5, #T_3a944_row9_col6, #T_3a944_row10_col0, #T_3a944_row10_col1, #T_3a944_row10_col2, #T_3a944_row10_col3, #T_3a944_row10_col4, #T_3a944_row10_col5, #T_3a944_row10_col6, #T_3a944_row11_col0, #T_3a944_row11_col1, #T_3a944_row11_col2, #T_3a944_row11_col3, #T_3a944_row11_col4, #T_3a944_row11_col5, #T_3a944_row11_col6, #T_3a944_row12_col0, #T_3a944_row12_col1, #T_3a944_row12_col2, #T_3a944_row12_col3, #T_3a944_row12_col4, #T_3a944_row12_col5, #T_3a944_row12_col6, #T_3a944_row13_col0, #T_3a944_row13_col1, #T_3a944_row13_col2, #T_3a944_row13_col3, #T_3a944_row13_col4, #T_3a944_row13_col5, #T_3a944_row13_col6, #T_3a944_row14_col0, #T_3a944_row14_col1, #T_3a944_row14_col2, #T_3a944_row14_col3, #T_3a944_row14_col4, #T_3a944_row14_col5, #T_3a944_row14_col6, #T_3a944_row15_col0, #T_3a944_row15_col1, #T_3a944_row15_col2, #T_3a944_row15_col3, #T_3a944_row15_col4, #T_3a944_row15_col5, #T_3a944_row15_col6, #T_3a944_row16_col0, #T_3a944_row16_col1, #T_3a944_row16_col2, #T_3a944_row16_col3, #T_3a944_row16_col4, #T_3a944_row16_col5, #T_3a944_row16_col6, #T_3a944_row17_col0, #T_3a944_row17_col1, #T_3a944_row17_col2, #T_3a944_row17_col3, #T_3a944_row17_col4, #T_3a944_row17_col5, #T_3a944_row17_col6, #T_3a944_row18_col0, #T_3a944_row18_col1, #T_3a944_row18_col2, #T_3a944_row18_col3, #T_3a944_row18_col4, #T_3a944_row18_col5, #T_3a944_row18_col6, #T_3a944_row19_col0, #T_3a944_row19_col1, #T_3a944_row19_col2, #T_3a944_row19_col3, #T_3a944_row19_col4, #T_3a944_row19_col5, #T_3a944_row19_col6 {
#   text-align: left;
# }
# #T_3a944_row0_col1, #T_3a944_row0_col2, #T_3a944_row0_col3, #T_3a944_row0_col4, #T_3a944_row0_col5, #T_3a944_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3a944_row0_col7, #T_3a944_row1_col7, #T_3a944_row2_col7, #T_3a944_row3_col7, #T_3a944_row4_col7, #T_3a944_row5_col7, #T_3a944_row6_col7, #T_3a944_row8_col7, #T_3a944_row9_col7, #T_3a944_row11_col7, #T_3a944_row12_col7, #T_3a944_row13_col7, #T_3a944_row14_col7, #T_3a944_row15_col7, #T_3a944_row16_col7, #T_3a944_row17_col7, #T_3a944_row18_col7, #T_3a944_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %% [markdown]
# ##  4. 모델 조정: 회귀 모델의 하이퍼 파라미터를 자동으로 조정하는 방법

# %%
cat = create_model('catboost')
# Out:
# <style type="text/css">
# #T_5b5ff_row10_col0, #T_5b5ff_row10_col1, #T_5b5ff_row10_col2, #T_5b5ff_row10_col3, #T_5b5ff_row10_col4, #T_5b5ff_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_5b5ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b5ff_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_5b5ff_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_5b5ff_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_5b5ff_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_5b5ff_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_5b5ff_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b5ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b5ff_row0_col0" class="data row0 col0" >539.5566</td>
#       <td id="T_5b5ff_row0_col1" class="data row0 col1" >785531.2982</td>
#       <td id="T_5b5ff_row0_col2" class="data row0 col2" >886.3020</td>
#       <td id="T_5b5ff_row0_col3" class="data row0 col3" >0.9914</td>
#       <td id="T_5b5ff_row0_col4" class="data row0 col4" >0.0681</td>
#       <td id="T_5b5ff_row0_col5" class="data row0 col5" >0.0489</td>
#     </tr>
#     <tr>
#       <th id="T_5b5ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b5ff_row1_col0" class="data row1 col0" >744.2238</td>
#       <td id="T_5b5ff_row1_col1" class="data row1 col1" >4740496.6476</td>
#       <td id="T_5b5ff_row1_col2" class="data row1 col2" >2177.2682</td>
#       <td id="T_5b5ff_row1_col3" class="data row1 col3" >0.9637</td>
#       <td id="T_5b5ff_row1_col4" class="data row1 col4" >0.0661</td>
#       <td id="T_5b5ff_row1_col5" class="data row1 col5" >0.0484</td>
#     </tr>
#     <tr>
#       <th id="T_5b5ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b5ff_row2_col0" class="data row2 col0" >641.1891</td>
#       <td id="T_5b5ff_row2_col1" class="data row2 col1" >1555529.8003</td>
#       <td id="T_5b5ff_row2_col2" class="data row2 col2" >1247.2088</td>
#       <td id="T_5b5ff_row2_col3" class="data row2 col3" >0.9857</td>
#       <td id="T_5b5ff_row2_col4" class="data row2 col4" >0.0692</td>
#       <td id="T_5b5ff_row2_col5" class="data row2 col5" >0.0519</td>
#     </tr>
#     <tr>
#       <th id="T_5b5ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b5ff_row3_col0" class="data row3 col0" >561.4647</td>
#       <td id="T_5b5ff_row3_col1" class="data row3 col1" >878314.3357</td>
#       <td id="T_5b5ff_row3_col2" class="data row3 col2" >937.1843</td>
#       <td id="T_5b5ff_row3_col3" class="data row3 col3" >0.9903</td>
#       <td id="T_5b5ff_row3_col4" class="data row3 col4" >0.0579</td>
#       <td id="T_5b5ff_row3_col5" class="data row3 col5" >0.0454</td>
#     </tr>
#     <tr>
#       <th id="T_5b5ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b5ff_row4_col0" class="data row4 col0" >580.0209</td>
#       <td id="T_5b5ff_row4_col1" class="data row4 col1" >1556406.3873</td>
#       <td id="T_5b5ff_row4_col2" class="data row4 col2" >1247.5602</td>
#       <td id="T_5b5ff_row4_col3" class="data row4 col3" >0.9806</td>
#       <td id="T_5b5ff_row4_col4" class="data row4 col4" >0.0676</td>
#       <td id="T_5b5ff_row4_col5" class="data row4 col5" >0.0479</td>
#     </tr>
#     <tr>
#       <th id="T_5b5ff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5b5ff_row5_col0" class="data row5 col0" >671.0877</td>
#       <td id="T_5b5ff_row5_col1" class="data row5 col1" >4497706.2283</td>
#       <td id="T_5b5ff_row5_col2" class="data row5 col2" >2120.7796</td>
#       <td id="T_5b5ff_row5_col3" class="data row5 col3" >0.9616</td>
#       <td id="T_5b5ff_row5_col4" class="data row5 col4" >0.0681</td>
#       <td id="T_5b5ff_row5_col5" class="data row5 col5" >0.0487</td>
#     </tr>
#     <tr>
#       <th id="T_5b5ff_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5b5ff_row6_col0" class="data row6 col0" >598.7914</td>
#       <td id="T_5b5ff_row6_col1" class="data row6 col1" >1493577.5702</td>
#       <td id="T_5b5ff_row6_col2" class="data row6 col2" >1222.1201</td>
#       <td id="T_5b5ff_row6_col3" class="data row6 col3" >0.9860</td>
#       <td id="T_5b5ff_row6_col4" class="data row6 col4" >0.0643</td>
#       <td id="T_5b5ff_row6_col5" class="data row6 col5" >0.0471</td>
#     </tr>
#     <tr>
#       <th id="T_5b5ff_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5b5ff_row7_col0" class="data row7 col0" >653.4854</td>
#       <td id="T_5b5ff_row7_col1" class="data row7 col1" >1728557.3404</td>
#       <td id="T_5b5ff_row7_col2" class="data row7 col2" >1314.7461</td>
#       <td id="T_5b5ff_row7_col3" class="data row7 col3" >0.9781</td>
#       <td id="T_5b5ff_row7_col4" class="data row7 col4" >0.0681</td>
#       <td id="T_5b5ff_row7_col5" class="data row7 col5" >0.0505</td>
#     </tr>
#     <tr>
#       <th id="T_5b5ff_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5b5ff_row8_col0" class="data row8 col0" >583.4590</td>
#       <td id="T_5b5ff_row8_col1" class="data row8 col1" >1038864.6744</td>
#       <td id="T_5b5ff_row8_col2" class="data row8 col2" >1019.2471</td>
#       <td id="T_5b5ff_row8_col3" class="data row8 col3" >0.9898</td>
#       <td id="T_5b5ff_row8_col4" class="data row8 col4" >0.0605</td>
#       <td id="T_5b5ff_row8_col5" class="data row8 col5" >0.0467</td>
#     </tr>
#     <tr>
#       <th id="T_5b5ff_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5b5ff_row9_col0" class="data row9 col0" >686.1993</td>
#       <td id="T_5b5ff_row9_col1" class="data row9 col1" >2169862.4680</td>
#       <td id="T_5b5ff_row9_col2" class="data row9 col2" >1473.0453</td>
#       <td id="T_5b5ff_row9_col3" class="data row9 col3" >0.9793</td>
#       <td id="T_5b5ff_row9_col4" class="data row9 col4" >0.0784</td>
#       <td id="T_5b5ff_row9_col5" class="data row9 col5" >0.0541</td>
#     </tr>
#     <tr>
#       <th id="T_5b5ff_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5b5ff_row10_col0" class="data row10 col0" >625.9478</td>
#       <td id="T_5b5ff_row10_col1" class="data row10 col1" >2044484.6750</td>
#       <td id="T_5b5ff_row10_col2" class="data row10 col2" >1364.5462</td>
#       <td id="T_5b5ff_row10_col3" class="data row10 col3" >0.9807</td>
#       <td id="T_5b5ff_row10_col4" class="data row10 col4" >0.0668</td>
#       <td id="T_5b5ff_row10_col5" class="data row10 col5" >0.0490</td>
#     </tr>
#     <tr>
#       <th id="T_5b5ff_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5b5ff_row11_col0" class="data row11 col0" >60.7628</td>
#       <td id="T_5b5ff_row11_col1" class="data row11 col1" >1346821.8364</td>
#       <td id="T_5b5ff_row11_col2" class="data row11 col2" >427.1983</td>
#       <td id="T_5b5ff_row11_col3" class="data row11 col3" >0.0100</td>
#       <td id="T_5b5ff_row11_col4" class="data row11 col4" >0.0052</td>
#       <td id="T_5b5ff_row11_col5" class="data row11 col5" >0.0025</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
#trained model object is stored in the variable 'dt'. 
print(cat)
# Out:
# <catboost.core.CatBoostRegressor object at 0x17af98e80>

# %%
lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_53331_row10_col0, #T_53331_row10_col1, #T_53331_row10_col2, #T_53331_row10_col3, #T_53331_row10_col4, #T_53331_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_53331">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53331_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_53331_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_53331_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_53331_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_53331_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_53331_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53331_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_30aea_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_30aea_row2_col0" class="data row2 col0" >946.6247</td>
#       <td id="T_30aea_row2_col1" class="data row2 col1" >3302237.0508</td>
#       <td id="T_30aea_row2_col2" class="data row2 col2" >1817.2058</td>
#       <td id="T_30aea_row2_col3" class="data row2 col3" >0.9697</td>
#       <td id="T_30aea_row2_col4" class="data row2 col4" >0.0979</td>
#       <td id="T_30aea_row2_col5" class="data row2 col5" >0.0743</td>
#     </tr>
#     <tr>
#       <th id="T_30aea_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_30aea_row3_col0" class="data row3 col0" >998.2012</td>
#       <td id="T_30aea_row3_col1" class="data row3 col1" >4045030.0662</td>
#       <td id="T_30aea_row3_col2" class="data row3 col2" >2011.2260</td>
#       <td id="T_30aea_row3_col3" class="data row3 col3" >0.9554</td>
#       <td id="T_30aea_row3_col4" class="data row3 col4" >0.1065</td>
#       <td id="T_30aea_row3_col5" class="data row3 col5" >0.0775</td>
#     </tr>
#     <tr>
#       <th id="T_30aea_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_30aea_row4_col0" class="data row4 col0" >1165.3572</td>
#       <td id="T_30aea_row4_col1" class="data row4 col1" >10351092.5985</td>
#       <td id="T_30aea_row4_col2" class="data row4 col2" >3217.3114</td>
#       <td id="T_30aea_row4_col3" class="data row4 col3" >0.8709</td>
#       <td id="T_30aea_row4_col4" class="data row4 col4" >0.1231</td>
#       <td id="T_30aea_row4_col5" class="data row4 col5" >0.0865</td>
#     </tr>
#     <tr>
#       <th id="T_30aea_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_30aea_row5_col0" class="data row5 col0" >1132.5243</td>
#       <td id="T_30aea_row5_col1" class="data row5 col1" >8077728.9074</td>
#       <td id="T_30aea_row5_col2" class="data row5 col2" >2842.1346</td>
#       <td id="T_30aea_row5_col3" class="data row5 col3" >0.9311</td>
#       <td id="T_30aea_row5_col4" class="data row5 col4" >0.1166</td>
#       <td id="T_30aea_row5_col5" class="data row5 col5" >0.0829</td>
#     </tr>
#     <tr>
#       <th id="T_30aea_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_30aea_row6_col0" class="data row6 col0" >983.2747</td>
#       <td id="T_30aea_row6_col1" class="data row6 col1" >3873840.0874</td>
#       <td id="T_30aea_row6_col2" class="data row6 col2" >1968.2073</td>
#       <td id="T_30aea_row6_col3" class="data row6 col3" >0.9636</td>
#       <td id="T_30aea_row6_col4" class="data row6 col4" >0.1056</td>
#       <td id="T_30aea_row6_col5" class="data row6 col5" >0.0779</td>
#     </tr>
#     <tr>
#       <th id="T_30aea_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_30aea_row7_col0" class="data row7 col0" >929.2234</td>
#       <td id="T_30aea_row7_col1" class="data row7 col1" >3288503.9800</td>
#       <td id="T_30aea_row7_col2" class="data row7 col2" >1813.4233</td>
#       <td id="T_30aea_row7_col3" class="data row7 col3" >0.9584</td>
#       <td id="T_30aea_row7_col4" class="data row7 col4" >0.0995</td>
#       <td id="T_30aea_row7_col5" class="data row7 col5" >0.0745</td>
#     </tr>
#     <tr>
#       <th id="T_30aea_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_30aea_row8_col0" class="data row8 col0" >941.5333</td>
#       <td id="T_30aea_row8_col1" class="data row8 col1" >3824830.7704</td>
#       <td id="T_30aea_row8_col2" class="data row8 col2" >1955.7175</td>
#       <td id="T_30aea_row8_col3" class="data row8 col3" >0.9624</td>
#       <td id="T_30aea_row8_col4" class="data row8 col4" >0.1025</td>
#       <td id="T_30aea_row8_col5" class="data row8 col5" >0.0727</td>
#     </tr>
#     <tr>
#       <th id="T_30aea_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_30aea_row9_col0" class="data row9 col0" >1031.7938</td>
#       <td id="T_30aea_row9_col1" class="data row9 col1" >4737518.0629</td>
#       <td id="T_30aea_row9_col2" class="data row9 col2" >2176.5840</td>
#       <td id="T_30aea_row9_col3" class="data row9 col3" >0.9549</td>
#       <td id="T_30aea_row9_col4" class="data row9 col4" >0.1209</td>
#       <td id="T_30aea_row9_col5" class="data row9 col5" >0.0836</td>
#     </tr>
#     <tr>
#       <th id="T_30aea_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_30aea_row10_col0" class="data row10 col0" >1011.9136</td>
#       <td id="T_30aea_row10_col1" class="data row10 col1" >5382439.9624</td>
#       <td id="T_30aea_row10_col2" class="data row10 col2" >2244.3755</td>
#       <td id="T_30aea_row10_col3" class="data row10 col3" >0.9465</td>
#       <td id="T_30aea_row10_col4" class="data row10 col4" >0.1082</td>
#       <td id="T_30aea_row10_col5" class="data row10 col5" >0.0779</td>
#     </tr>
#     <tr>
#       <th id="T_30aea_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_30aea_row11_col0" class="data row11 col0" >99.9948</td>
#       <td id="T_30aea_row11_col1" class="data row11 col1" >2866700.9171</td>
#       <td id="T_30aea_row11_col2" class="data row11 col2" >587.5532</td>
#       <td id="T_30aea_row11_col3" class="data row11 col3" >0.0298</td>
#       <td id="T_30aea_row11_col4" class="data row11 col4" >0.0084</td>
#       <td id="T_30aea_row11_col5" class="data row11 col5" >0.0046</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
tuned_cat = tune_model(cat)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   17:04:06
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .         CatBoost Regressor
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
#tuned model object is stored in the variable 'tuned_dt'. 
print(tuned_cat)
# Out:
# <catboost.core.CatBoostRegressor object at 0x17afd4d90>

# %%
tuned_lightgbm = tune_model(lightgbm)
# Out:
# <style type="text/css">
# #T_e03fd_row10_col0, #T_e03fd_row10_col1, #T_e03fd_row10_col2, #T_e03fd_row10_col3, #T_e03fd_row10_col4, #T_e03fd_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e03fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e03fd_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_e03fd_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_e03fd_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_e03fd_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_e03fd_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_e03fd_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e03fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e03fd_row0_col0" class="data row0 col0" >789.6479</td>
#       <td id="T_e03fd_row0_col1" class="data row0 col1" >1618172.3749</td>
#       <td id="T_e03fd_row0_col2" class="data row0 col2" >1272.0740</td>
#       <td id="T_e03fd_row0_col3" class="data row0 col3" >0.9822</td>
#       <td id="T_e03fd_row0_col4" class="data row0 col4" >0.1074</td>
#       <td id="T_e03fd_row0_col5" class="data row0 col5" >0.0751</td>
#     </tr>
#     <tr>
#       <th id="T_e03fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e03fd_row1_col0" class="data row1 col0" >951.7881</td>
#       <td id="T_e03fd_row1_col1" class="data row1 col1" >7322635.7387</td>
#       <td id="T_e03fd_row1_col2" class="data row1 col2" >2706.0369</td>
#       <td id="T_e03fd_row1_col3" class="data row1 col3" >0.9439</td>
#       <td id="T_e03fd_row1_col4" class="data row1 col4" >0.1073</td>
#       <td id="T_e03fd_row1_col5" class="data row1 col5" >0.0709</td>
#     </tr>
#     <tr>
#       <th id="T_e03fd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e03fd_row2_col0" class="data row2 col0" >935.3023</td>
#       <td id="T_e03fd_row2_col1" class="data row2 col1" >3795745.1612</td>
#       <td id="T_e03fd_row2_col2" class="data row2 col2" >1948.2672</td>
#       <td id="T_e03fd_row2_col3" class="data row2 col3" >0.9652</td>
#       <td id="T_e03fd_row2_col4" class="data row2 col4" >0.1114</td>
#       <td id="T_e03fd_row2_col5" class="data row2 col5" >0.0795</td>
#     </tr>
#     <tr>
#       <th id="T_e03fd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e03fd_row3_col0" class="data row3 col0" >779.3574</td>
#       <td id="T_e03fd_row3_col1" class="data row3 col1" >2108938.0300</td>
#       <td id="T_e03fd_row3_col2" class="data row3 col2" >1452.2183</td>
#       <td id="T_e03fd_row3_col3" class="data row3 col3" >0.9767</td>
#       <td id="T_e03fd_row3_col4" class="data row3 col4" >0.0936</td>
#       <td id="T_e03fd_row3_col5" class="data row3 col5" >0.0677</td>
#     </tr>
#     <tr>
#       <th id="T_e03fd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e03fd_row4_col0" class="data row4 col0" >835.6063</td>
#       <td id="T_e03fd_row4_col1" class="data row4 col1" >2188709.7918</td>
#       <td id="T_e03fd_row4_col2" class="data row4 col2" >1479.4289</td>
#       <td id="T_e03fd_row4_col3" class="data row4 col3" >0.9727</td>
#       <td id="T_e03fd_row4_col4" class="data row4 col4" >0.1142</td>
#       <td id="T_e03fd_row4_col5" class="data row4 col5" >0.0820</td>
#     </tr>
#     <tr>
#       <th id="T_e03fd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e03fd_row5_col0" class="data row5 col0" >947.5317</td>
#       <td id="T_e03fd_row5_col1" class="data row5 col1" >6840442.6242</td>
#       <td id="T_e03fd_row5_col2" class="data row5 col2" >2615.4240</td>
#       <td id="T_e03fd_row5_col3" class="data row5 col3" >0.9416</td>
#       <td id="T_e03fd_row5_col4" class="data row5 col4" >0.1035</td>
#       <td id="T_e03fd_row5_col5" class="data row5 col5" >0.0730</td>
#     </tr>
#     <tr>
#       <th id="T_e03fd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e03fd_row6_col0" class="data row6 col0" >923.0091</td>
#       <td id="T_e03fd_row6_col1" class="data row6 col1" >4059964.4133</td>
#       <td id="T_e03fd_row6_col2" class="data row6 col2" >2014.9353</td>
#       <td id="T_e03fd_row6_col3" class="data row6 col3" >0.9619</td>
#       <td id="T_e03fd_row6_col4" class="data row6 col4" >0.0991</td>
#       <td id="T_e03fd_row6_col5" class="data row6 col5" >0.0701</td>
#     </tr>
#     <tr>
#       <th id="T_e03fd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e03fd_row7_col0" class="data row7 col0" >892.5534</td>
#       <td id="T_e03fd_row7_col1" class="data row7 col1" >3052839.2926</td>
#       <td id="T_e03fd_row7_col2" class="data row7 col2" >1747.2376</td>
#       <td id="T_e03fd_row7_col3" class="data row7 col3" >0.9614</td>
#       <td id="T_e03fd_row7_col4" class="data row7 col4" >0.1051</td>
#       <td id="T_e03fd_row7_col5" class="data row7 col5" >0.0775</td>
#     </tr>
#     <tr>
#       <th id="T_e03fd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e03fd_row8_col0" class="data row8 col0" >831.6812</td>
#       <td id="T_e03fd_row8_col1" class="data row8 col1" >2509335.3742</td>
#       <td id="T_e03fd_row8_col2" class="data row8 col2" >1584.0882</td>
#       <td id="T_e03fd_row8_col3" class="data row8 col3" >0.9754</td>
#       <td id="T_e03fd_row8_col4" class="data row8 col4" >0.0868</td>
#       <td id="T_e03fd_row8_col5" class="data row8 col5" >0.0670</td>
#     </tr>
#     <tr>
#       <th id="T_e03fd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e03fd_row9_col0" class="data row9 col0" >835.2462</td>
#       <td id="T_e03fd_row9_col1" class="data row9 col1" >3138654.3258</td>
#       <td id="T_e03fd_row9_col2" class="data row9 col2" >1771.6248</td>
#       <td id="T_e03fd_row9_col3" class="data row9 col3" >0.9701</td>
#       <td id="T_e03fd_row9_col4" class="data row9 col4" >0.1125</td>
#       <td id="T_e03fd_row9_col5" class="data row9 col5" >0.0762</td>
#     </tr>
#     <tr>
#       <th id="T_e03fd_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_
_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_70a7a_row11_col0" class="data row11 col0" >78.3457</td>
#       <td id="T_70a7a_row11_col1" class="data row11 col1" >2414683.2859</td>
#       <td id="T_70a7a_row11_col2" class="data row11 col2" >484.9798</td>
#       <td id="T_70a7a_row11_col3" class="data row11 col3" >0.0227</td>
#       <td id="T_70a7a_row11_col4" class="data row11 col4" >0.0068</td>
#       <td id="T_70a7a_row11_col5" class="data row11 col5" >0.0030</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
print(tuned_dt)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=10, max_features=1.0,
#                       min_impurity_decrease=0.01, min_samples_leaf=2,
#                       min_samples_split=9, random_state=123)

# %% [markdown]
# ## 5. 모델 플롯: 다양한 플롯을 사용하여 모델 성능을 분석하는 방법

# %%
plot_model(tuned_lightgbm)

# %%
plot_model(tuned_lightgbm, plot = 'error')

# %%
plot_model(tuned_lightgbm, plot='feature')

# %% [markdown]
# ## 6. 모델 마무리: 실험이 끝날 때 최적의 모델을 확정하는 방법

# %%
predict_model(tuned_lightgbm)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6f8a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f8a0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6f8a0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6f8a0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6f8a0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6f8a0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6f8a0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6f8a0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f8a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f8a0_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6f8a0_row0_col1" class="data row0 col1" >756.6163</td>
#       <td id="T_6f8a0_row0_col2" class="data row0 col2" >3595582.0751</td>
#       <td id="T_6f8a0_row0_col3" class="data row0 col3" >1896.2020</td>
#       <td id="T_6f8a0_row0_col4" class="data row0 col4" >0.9672</td>
#       <td id="T_6f8a0_row0_col5" class="data row0 col5" >0.0761</td>
#       <td id="T_6f8a0_row0_col6" class="data row0 col6" >0.0541</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_lightgbm = finalize_model(tuned_lightgbm)

# %%
#Final Light Gradient Boosting Machine parameters for deployment
print(final_lightgbm)
# Out:
# Pipeline(memory=FastMemory(location=/var/folders/h4/44486vyn1_xbs13g1z50l5m00000gn/T/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Carat Weight'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                              'Polish', 'Symmetry', 'Report'],
#                                     transformer=SimpleImputer(strategy='most_frequent')...
# dtype: int64}]))),
#                 ('onehot_encoding',
#                  TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                              'Polish', 'Symmetry'],
#                                     transformer=OneHotEncoder(cols=['Cut',
#                                                                     'Color',
#                                                                     'Clarity',
#                                                                     'Polish',
#                                                                     'Symmetry'],
#                                                               handle_missing='return_nan',
#                                                               use_cat_names=True))),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames())),
#                 ('actual_estimator', LGBMRegressor(random_state=123))])

# %%
predict_model(final_lightgbm);
# Out:
# <style type="text/css">
# </style>
# <table id="T_33e4a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33e4a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_33e4a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_33e4a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_33e4a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_33e4a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_33e4a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_33e4a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33e4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33e4a_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_33e4a_row0_col1" class="data row0 col1" >552.0006</td>
#       <td id="T_33e4a_row0_col2" class="data row0 col2" >1342403.6706</td>
#       <td id="T_33e4a_row0_col3" class="data row0 col3" >1158.6215</td>
#       <td id="T_33e4a_row0_col4" class="data row0 col4" >0.9878</td>
#       <td id="T_33e4a_row0_col5" class="data row0 col5" >0.0611</td>
#       <td id="T_33e4a_row0_col6" class="data row0 col6" >0.0455</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 7. 모델 예측: 새로운 데이터/보이지 않는 데이터를 예측하는 방법

# %%
unseen_predictions = predict_model(final_lightgbm, data=data_unseen)
unseen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_85f07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85f07_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_85f07_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_85f07_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_85f07_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_85f07_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_85f07_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_85f07_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85f07_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85f07_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_85f07_row0_col1" class="data row0 col1" >726.1275</td>
#       <td id="T_85f07_row0_col2" class="data row0 col2" >2508012.9410</td>
#       <td id="T_85f07_row0_col3" class="data row0 col3" >1583.6707</td>
#       <td id="T_85f07_row0_col4" class="data row0 col4" >0.9756</td>
#       <td id="T_85f07_row0_col5" class="data row0 col5" >0.0739</td>
#       <td id="T_85f07_row0_col6" class="data row0 col6" >0.0542</td>
#     </tr>
#   </tbody>
# </table>
#     Carat Weight        Cut Color Clarity Polish Symmetry Report  Price  \
# 5           1.53      Ideal     E     SI1     ID       ID   AGSL  12791
# 7           1.50       Fair     F     SI1     VG       VG    GIA  10450
# 11          1.01       Good     E     SI1      G        G    GIA   5161
# 13          2.51  Very Good     G     VS2     VG       VG    GIA  34361
# 18          1.01       Good     I     SI1     VG       VG    GIA   4238
#
#     prediction_label
# 5       12373.585508
# 7       10272.344020
# 11       4967.753011
# 13      34944.474773
# 18       4166.156729

# %% [markdown]
# ## 8. 모델 저장/로드: 나중에 사용하기 위해 모델을 저장/로드하는 방법

# %%
save_model(final_lightgbm,'Final Lightgbm Model 08Feb2020')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/var/folders/h4/44486vyn1_xbs13g1z50l5m00000gn/T/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Carat Weight'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                               'Polish', 'Symmetry', 'Report'],
#                                      transformer=SimpleImputer(strategy='most_frequent')...
#  dtype: int64}]))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                               'Polish', 'Symmetry'],
#                                      transformer=OneHotEncoder(cols=['Cut',
#                                                                      'Color',
#                                                                      'Clarity',
#                                                                      'Polish',
#                                                                      'Symmetry'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('actual_estimator', LGBMRegressor(random_state=123))]),
#  'Final Lightgbm Model 08Feb2020.pkl')

# %%
saved_final_lightgbm = load_model('Final Lightgbm Model 08Feb2020')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_prediction = predict_model(saved_final_lightgbm, data=data_unseen)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ffa96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffa96_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ffa96_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ffa96_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ffa96_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ffa96_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ffa96_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ffa96_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffa96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ffa96_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ffa96_row0_col1" class="data row0 col1" >726.1275</td>
#       <td id="T_ffa96_row0_col2" class="data row0 col2" >2508012.9410</td>
#       <td id="T_ffa96_row0_col3" class="data row0 col3" >1583.6707</td>
#       <td id="T_ffa96_row0_col4" class="data row0 col4" >0.9756</td>
#       <td id="T_ffa96_row0_col5" class="data row0 col5" >0.0739</td>
#       <td id="T_ffa96_row0_col6" class="data row0 col6" >0.0542</td>
#     </tr>
#   </tbody>
# </table>

# %%
new_prediction.head()
# Out:
#     Carat Weight        Cut Color Clarity Polish Symmetry Report  Price  \
# 5           1.53      Ideal     E     SI1     ID       ID   AGSL  12791
# 7           1.50       Fair     F     SI1     VG       VG    GIA  10450
# 11          1.01       Good     E     SI1      G        G    GIA   5161
# 13          2.51  Very Good     G     VS2     VG       VG    GIA  34361
# 18          1.01       Good     I     SI1     VG       VG    GIA   4238
#
#     prediction_label
# 5       12373.585508
# 7       10272.344020
# 11       4967.753011
# 13      34944.474773
# 18       4166.156729
