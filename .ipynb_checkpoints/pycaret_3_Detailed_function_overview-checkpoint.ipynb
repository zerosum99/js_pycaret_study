# %% [markdown]
# ## 참고자료
#
# https://github.com/pycaret/pycaret/blob/master/tutorials/Tutorial%20-%20Regression.ipynb

# %% [markdown]
# ## Detailed function-by-function overview

# %%
from pycaret.datasets import get_data
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# import pycaret regression and init setup
from pycaret.regression import *

# %% [markdown]
# ## SetUp
#
#
# - 설정 함수는 PyCaret에서 실험을 초기화하고 함수에서 전달된 모든 매개변수를 기반으로 변환 파이프라인을 생성합니다.
# - 설정 함수는 다른 함수를 실행하기 전에 반드시 호출해야 합니다.
# - 데이터와 대상이라는 두 가지 필수 파라미터가 필요합니다.
# - 다른 모든 파라미터는 선택 사항이며 데이터 전처리 파이프라인을 구성하는 데 사용됩니다.

# %%
s = setup(data, target = 'charges', session_id = 123)
# Out:
# <style type="text/css">
# #T_4a29a_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4a29a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a29a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4a29a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a29a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a29a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4a29a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a29a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4a29a_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a29a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4a29a_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a29a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4a29a_row3_col1" class="data row3 col1" >(1338, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a29a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4a29a_row4_col1" class="data row4 col1" >(1338, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a29a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4a29a_row5_col1" class="data row5 col1" >(936, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4a29a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4a29a_row6_col1" class="data row6 col1" >(402, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4a29a_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_4a29a_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4a29a_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_4a29a_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4a29a_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_4a29a_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4a29a_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_4a29a_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4a29a_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_4a29a_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4a29a_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_4a29a_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4a29a_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_4a29a_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4a29a_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_4a29a_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4a29a_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_4a29a_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4a29a_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_4a29a_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4a29a_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_4a29a_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4a29a_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_4a29a_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4a29a_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_4a29a_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4a29a_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_4a29a_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4a29a_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_4a29a_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4a29a_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_4a29a_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_4a29a_row22_col1" class="data row22 col1" >3cbf</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 구성
#
# 변환된 데이터셋, 랜덤스테이트 등 설정 함수에 의해 생성된 모든 변수에 액세스하려면 get_config 메서드를 사용할 수 있습니다.

# %%
# check all available config
get_config()
# Out:
# {'USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_available_plots',
#  '_ml_usecase',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'exp_id',
#  'exp_name_log',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'gpu_n_jobs_param',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'is_multiclass',
#  'log_plots_param',
#  'logging_param',
#  'memory',
#  'n_jobs_param',
#  'pipeline',
#  'seed',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'transform_target_param',
#  'variable_and_property_keys',
#  'variables',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed'}

# %%
# lets access X_train_transformed
get_config('X_train_transformed')
# Out:
#        age  sex        bmi  children  smoker  region_northeast  \
# 300   36.0  1.0  27.549999       3.0     0.0               1.0
# 904   60.0  0.0  35.099998       0.0     0.0               0.0
# 670   30.0  1.0  31.570000       3.0     0.0               0.0
# 617   49.0  1.0  25.600000       2.0     1.0               0.0
# 373   26.0  1.0  32.900002       2.0     1.0               0.0
# ...    ...  ...        ...       ...     ...               ...
# 1238  37.0  1.0  22.705000       3.0     0.0               1.0
# 1147  20.0  0.0  31.920000       0.0     0.0               0.0
# 106   19.0  0.0  28.400000       1.0     0.0               0.0
# 1041  18.0  1.0  23.084999       0.0     0.0               1.0
# 1122  53.0  0.0  36.860001       3.0     1.0               0.0
#
#       region_southwest  region_southeast  region_northwest
# 300                0.0               0.0               0.0
# 904                1.0               0.0               0.0
# 670                0.0               1.0               0.0
# 617                1.0               0.0               0.0
# 373                1.0               0.0               0.0
# ...                ...               ...               ...
# 1238               0.0               0.0               0.0
# 1147               0.0               0.0               1.0
# 106                1.0               0.0               0.0
# 1041               0.0               0.0               0.0
# 1122               0.0               0.0               1.0
#
# [936 rows x 9 columns]

# %%
# another example: let's access seed
print("The current seed is: {}".format(get_config('seed')))

# now lets change it using set_config
set_config('seed', 786)
print("The new seed is: {}".format(get_config('seed')))
# Out:
# The current seed is: 123
# The new seed is: 786

# %% [markdown]
# ## setup 매개변수 지정
#
# 모든 전처리 구성과 실험 설정/파라미터는 설정 기능으로 전달됩니다. 사용 가능한 모든 파라미터를 보려면 문서 문자열을 확인하세요:

# %%
# init setup with normalize = True
s = setup(data, target = 'charges', session_id = 123,
          normalize = True, normalize_method = 'minmax')
# Out:
# <style type="text/css">
# #T_98a2c_row10_col1, #T_98a2c_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_98a2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98a2c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_98a2c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98a2c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98a2c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_98a2c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98a2c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_98a2c_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98a2c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_98a2c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98a2c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_98a2c_row3_col1" class="data row3 col1" >(1338, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_98a2c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_98a2c_row4_col1" class="data row4 col1" >(1338, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_98a2c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_98a2c_row5_col1" class="data row5 col1" >(936, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_98a2c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_98a2c_row6_col1" class="data row6 col1" >(402, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_98a2c_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_98a2c_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_98a2c_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_98a2c_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_98a2c_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_98a2c_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_98a2c_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_98a2c_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_98a2c_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_98a2c_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_98a2c_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_98a2c_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_98a2c_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_98a2c_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_98a2c_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_98a2c_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_98a2c_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_98a2c_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_98a2c_row16_col0" class="data row16 col0" >Normalize</td>
#       <td id="T_98a2c_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_98a2c_row17_col0" class="data row17 col0" >Normalize method</td>
#       <td id="T_98a2c_row17_col1" class="data row17 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_98a2c_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_98a2c_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_98a2c_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_98a2c_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_98a2c_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_98a2c_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_98a2c_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_98a2c_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_98a2c_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_98a2c_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_98a2c_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_98a2c_row23_col1" class="data row23 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_98a2c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_98a2c_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_98a2c_row24_col1" class="data row24 col1" >bf40</td>
#     </tr>
#   </tbody>
# </table>

# %%
# lets check the X_train_transformed to see effect of params passed
get_config('X_train_transformed')['age'].hist()
# Out:
# <AxesSubplot: >

# %%
get_config('X_train')['age'].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Compare Models
#
# compare_models 함수는 교차 검증을 사용하여 모델 라이브러리에서 사용할 수 있는 모든 추정기의 성능을 학습하고 평가합니다. 이 함수의 출력은 교차 검증 평균 점수가 포함된 점수 그리드입니다. CV 중에 평가된 지표는 get_metrics 함수를 사용하여 액세스할 수 있습니다. 사용자 지정 지표는 add_metric 및 remove_metric 함수를 사용하여 추가하거나 제거할 수 있습니다.
#
#
# - Some other parameters that you might find very useful in compare_models are:
#
# > fold
# > cross_validation
# > budget_time
# > errors
# > probability_threshold
# > parallel

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_ce398 th {
#   text-align: left;
# }
# #T_ce398_row0_col0, #T_ce398_row0_col6, #T_ce398_row1_col0, #T_ce398_row1_col1, #T_ce398_row1_col2, #T_ce398_row1_col3, #T_ce398_row1_col4, #T_ce398_row1_col5, #T_ce398_row1_col6, #T_ce398_row2_col0, #T_ce398_row2_col1, #T_ce398_row2_col2, #T_ce398_row2_col3, #T_ce398_row2_col4, #T_ce398_row2_col5, #T_ce398_row2_col6, #T_ce398_row3_col0, #T_ce398_row3_col1, #T_ce398_row3_col2, #T_ce398_row3_col3, #T_ce398_row3_col4, #T_ce398_row3_col5, #T_ce398_row3_col6, #T_ce398_row4_col0, #T_ce398_row4_col1, #T_ce398_row4_col2, #T_ce398_row4_col3, #T_ce398_row4_col4, #T_ce398_row4_col5, #T_ce398_row4_col6, #T_ce398_row5_col0, #T_ce398_row5_col1, #T_ce398_row5_col2, #T_ce398_row5_col3, #T_ce398_row5_col4, #T_ce398_row5_col5, #T_ce398_row5_col6, #T_ce398_row6_col0, #T_ce398_row6_col1, #T_ce398_row6_col2, #T_ce398_row6_col3, #T_ce398_row6_col4, #T_ce398_row6_col5, #T_ce398_row6_col6, #T_ce398_row7_col0, #T_ce398_row7_col1, #T_ce398_row7_col2, #T_ce398_row7_col3, #T_ce398_row7_col4, #T_ce398_row7_col5, #T_ce398_row7_col6, #T_ce398_row8_col0, #T_ce398_row8_col1, #T_ce398_row8_col2, #T_ce398_row8_col3, #T_ce398_row8_col4, #T_ce398_row8_col5, #T_ce398_row8_col6, #T_ce398_row9_col0, #T_ce398_row9_col1, #T_ce398_row9_col2, #T_ce398_row9_col3, #T_ce398_row9_col4, #T_ce398_row9_col5, #T_ce398_row9_col6, #T_ce398_row10_col0, #T_ce398_row10_col1, #T_ce398_row10_col2, #T_ce398_row10_col3, #T_ce398_row10_col4, #T_ce398_row10_col5, #T_ce398_row10_col6, #T_ce398_row11_col0, #T_ce398_row11_col1, #T_ce398_row11_col2, #T_ce398_row11_col3, #T_ce398_row11_col4, #T_ce398_row11_col5, #T_ce398_row11_col6, #T_ce398_row12_col0, #T_ce398_row12_col1, #T_ce398_row12_col2, #T_ce398_row12_col3, #T_ce398_row12_col4, #T_ce398_row12_col5, #T_ce398_row12_col6, #T_ce398_row13_col0, #T_ce398_row13_col1, #T_ce398_row13_col2, #T_ce398_row13_col3, #T_ce398_row13_col4, #T_ce398_row13_col5, #T_ce398_row13_col6, #T_ce398_row14_col0, #T_ce398_row14_col1, #T_ce398_row14_col2, #T_ce398_row14_col3, #T_ce398_row14_col4, #T_ce398_row14_col5, #T_ce398_row15_col0, #T_ce398_row15_col1, #T_ce398_row15_col2, #T_ce398_row15_col3, #T_ce398_row15_col4, #T_ce398_row15_col5, #T_ce398_row15_col6, #T_ce398_row16_col0, #T_ce398_row16_col1, #T_ce398_row16_col2, #T_ce398_row16_col3, #T_ce398_row16_col4, #T_ce398_row16_col5, #T_ce398_row16_col6, #T_ce398_row17_col0, #T_ce398_row17_col1, #T_ce398_row17_col2, #T_ce398_row17_col3, #T_ce398_row17_col4, #T_ce398_row17_col5, #T_ce398_row17_col6, #T_ce398_row18_col0, #T_ce398_row18_col1, #T_ce398_row18_col2, #T_ce398_row18_col3, #T_ce398_row18_col4, #T_ce398_row18_col5, #T_ce398_row18_col6, #T_ce398_row19_col0, #T_ce398_row19_col1, #T_ce398_row19_col2, #T_ce398_row19_col3, #T_ce398_row19_col4, #T_ce398_row19_col5, #T_ce398_row19_col6 {
#   text-align: left;
# }
# #T_ce398_row0_col1, #T_ce398_row0_col2, #T_ce398_row0_col3, #T_ce398_row0_col4, #T_ce398_row0_col5, #T_ce398_row14_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ce398_row0_col7, #T_ce398_row1_col7, #T_ce398_row2_col7, #T_ce398_row3_col7, #T_ce398_row4_col7, #T_ce398_row5_col7, #T_ce398_row6_col7, #T_ce398_row7_col7, #T_ce398_row8_col7, #T_ce398_row9_col7, #T_ce398_row10_col7, #T_ce398_row11_col7, #T_ce398_row12_col7, #T_ce398_row13_col7, #T_ce398_row14_col7, #T_ce398_row15_col7, #T_ce398_row17_col7, #T_ce398_row18_col7, #T_ce398_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ce398_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ce398">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce398_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ce398_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ce398_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ce398_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ce398_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ce398_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ce398_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ce398_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce398_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_ce398_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ce398_row0_col1" class="data row0 col1" >2701.9135</td>
#       <td id="T_ce398_row0_col2" class="data row0 col2" >23548622.1598</td>
#       <td id="T_ce398_row0_col3" class="data row0 col3" >4832.9291</td>
#       <td id="T_ce398_row0_col4" class="data row0 col4" >0.8320</td>
#       <td id="T_ce398_row0_col5" class="data row0 col5" >0.4447</td>
#       <td id="T_ce398_row0_col6" class="data row0 col6" >0.3137</td>
#       <td id="T_ce398_row0_col7" class="data row0 col7" >0.4440</td>
#     </tr>
#     <tr>
#       <th id="T_ce398_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_ce398_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_ce398_row1_col1" class="data row1 col1" >2772.9195</td>
#       <td id="T_ce398_row1_col2" class="data row1 col2" >25409792.9692</td>
#       <td id="T_ce398_row1_col3" class="data row1 col3" >5028.1973</td>
#       <td id="T_ce398_row1_col4" class="data row1 col4" >0.8173</td>
#       <td id="T_ce398_row1_col5" class="data row1 col5" >0.4687</td>
#       <td id="T_ce398_row1_col6" class="data row1 col6" >0.3298</td>
#       <td id="T_ce398_row1_col7" class="data row1 col7" >0.4530</td>
#     </tr>
#     <tr>
#       <th id="T_ce398_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_ce398_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_ce398_row2_col1" class="data row2 col1" >2899.4825</td>
#       <td id="T_ce398_row2_col2" class="data row2 col2" >25762752.2096</td>
#       <td id="T_ce398_row2_col3" class="data row2 col3" >5057.5778</td>
#       <td id="T_ce398_row2_col4" class="data row2 col4" >0.8163</td>
#       <td id="T_ce398_row2_col5" class="data row2 col5" >0.4815</td>
#       <td id="T_ce398_row2_col6" class="data row2 col6" >0.3522</td>
#       <td id="T_ce398_row2_col7" class="data row2 col7" >0.5480</td>
#     </tr>
#     <tr>
#       <th id="T_ce398_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_ce398_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ce398_row3_col1" class="data row3 col1" >3001.8884</td>
#       <td id="T_ce398_row3_col2" class="data row3 col2" >25547324.5813</td>
#       <td id="T_ce398_row3_col3" class="data row3 col3" >5044.5767</td>
#       <td id="T_ce398_row3_col4" class="data row3 col4" >0.8147</td>
#       <td id="T_ce398_row3_col5" class="data row3 col5" >0.5445</td>
#       <td id="T_ce398_row3_col6" class="data row3 col6" >0.3784</td>
#       <td id="T_ce398_row3_col7" class="data row3 col7" >0.5130</td>
#     </tr>
#     <tr>
#       <th id="T_ce398_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_ce398_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_ce398_row4_col1" class="data row4 col1" >2833.3624</td>
#       <td id="T_ce398_row4_col2" class="data row4 col2" >28427844.2412</td>
#       <td id="T_ce398_row4_col3" class="data row4 col3" >5305.6516</td>
#       <td id="T_ce398_row4_col4" class="data row4 col4" >0.7991</td>
#       <td id="T_ce398_row4_col5" class="data row4 col5" >0.4877</td>
#       <td id="T_ce398_row4_col6" class="data row4 col6" >0.3363</td>
#       <td id="T_ce398_row4_col7" class="data row4 col7" >0.4540</td>
#     </tr>
#     <tr>
#       <th id="T_ce398_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_ce398_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_ce398_row5_col1" class="data row5 col1" >4175.5916</td>
#       <td id="T_ce398_row5_col2" class="data row5 col2" >2
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %%
# check available models
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# xgboost           Extreme Gradient Boosting
# lightgbm    Light Gradient Boosting Machine
# catboost                 CatBoost Regressor
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# xgboost                        xgboost.sklearn.XGBRegressor   True
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# catboost                    catboost.core.CatBoostRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %% [markdown]
# ## 모델매개변수 지정
#
# compare_models의 포함 및 제외 매개 변수를 사용하여 선택한 모델만 학습시키거나 제외 매개 변수에 모델 ID를 전달하여 특정 모델을 학습에서 제외할 수 있습니다.

# %%
compare_tree_models = compare_models(include = ['dt', 'rf', 'et', 'gbr', 'xgboost', 'lightgbm', 'catboost'])
# Out:
# <style type="text/css">
# #T_cfdef th {
#   text-align: left;
# }
# #T_cfdef_row0_col0, #T_cfdef_row1_col0, #T_cfdef_row1_col1, #T_cfdef_row1_col2, #T_cfdef_row1_col3, #T_cfdef_row1_col4, #T_cfdef_row1_col5, #T_cfdef_row1_col6, #T_cfdef_row2_col0, #T_cfdef_row2_col1, #T_cfdef_row2_col2, #T_cfdef_row2_col3, #T_cfdef_row2_col4, #T_cfdef_row2_col5, #T_cfdef_row2_col6, #T_cfdef_row3_col0, #T_cfdef_row3_col1, #T_cfdef_row3_col2, #T_cfdef_row3_col3, #T_cfdef_row3_col4, #T_cfdef_row3_col5, #T_cfdef_row3_col6, #T_cfdef_row4_col0, #T_cfdef_row4_col1, #T_cfdef_row4_col2, #T_cfdef_row4_col3, #T_cfdef_row4_col4, #T_cfdef_row4_col5, #T_cfdef_row4_col6, #T_cfdef_row5_col0, #T_cfdef_row5_col1, #T_cfdef_row5_col2, #T_cfdef_row5_col3, #T_cfdef_row5_col4, #T_cfdef_row5_col5, #T_cfdef_row5_col6, #T_cfdef_row6_col0, #T_cfdef_row6_col1, #T_cfdef_row6_col2, #T_cfdef_row6_col3, #T_cfdef_row6_col4, #T_cfdef_row6_col5, #T_cfdef_row6_col6 {
>0.4490</td>
#     </tr>
#     <tr>
#       <th id="T_cfdef_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_cfdef_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_cfdef_row5_col1" class="data row5 col1" >3439.8892</td>
#       <td id="T_cfdef_row5_col2" class="data row5 col2" >32826514.4000</td>
#       <td id="T_cfdef_row5_col3" class="data row5 col3" >5711.7335</td>
#       <td id="T_cfdef_row5_col4" class="data row5 col4" >0.7626</td>
#       <td id="T_cfdef_row5_col5" class="data row5 col5" >0.6221</td>
#       <td id="T_cfdef_row5_col6" class="data row5 col6" >0.4465</td>
#       <td id="T_cfdef_row5_col7" class="data row5 col7" >0.4300</td>
#     </tr>
#     <tr>
#       <th id="T_cfdef_level0_row6" class="row_heading level0 row6" >dt</th>
#       <td id="T_cfdef_row6_col0" class="data row6 col0" >Decision Tree Regressor</td>
#       <td id="T_cfdef_row6_col1" class="data row6 col1" >3399.1402</td>
#       <td id="T_cfdef_row6_col2" class="data row6 col2" >48100203.3847</td>
#       <td id="T_cfdef_row6_col3" class="data row6 col3" >6915.2984</td>
#       <td id="T_cfdef_row6_col4" class="data row6 col4" >0.6476</td>
#       <td id="T_cfdef_row6_col5" class="data row6 col5" >0.5629</td>
#       <td id="T_cfdef_row6_col6" class="data row6 col6" >0.4052</td>
#       <td id="T_cfdef_row6_col7" class="data row6 col7" >0.4470</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/33 [00:00<?, ?it/s]

# %%
compare_tree_models
# Out:
# GradientBoostingRegressor(random_state=123)

# %% [markdown]
# ## 모델 : pull 함수 사용
#
# 위의 함수는 학습된 모델 객체를 출력으로 반환합니다. 채점 그리드는 표시만 되고 반환되지 않습니다. 채점 그리드에 액세스해야 하는 경우 풀 함수를 사용하여 데이터 프레임에 액세스할 수 있습니다.

# %%
compare_tree_models_results = pull()
compare_tree_models_results
# Out:
#                                     Model        MAE           MSE       RMSE  \
# gbr           Gradient Boosting Regressor  2701.9135  2.354862e+07  4832.9291
# rf                Random Forest Regressor  2772.9195  2.540979e+07  5028.1973
# catboost               CatBoost Regressor  2899.4825  2.576275e+07  5057.5778
# lightgbm  Light Gradient Boosting Machine  3001.8884  2.554732e+07  5044.5767
# et                  Extra Trees Regressor  2833.3624  2.842784e+07  5305.6516
# xgboost         Extreme Gradient Boosting  3439.8892  3.282651e+07  5711.7335
# dt                Decision Tree Regressor  3399.1402  4.810020e+07  6915.2984
#
#               R2   RMSLE    MAPE  TT (Sec)
# gbr       0.8320  0.4447  0.3137     0.449
# rf        0.8173  0.4687  0.3298     0.455
# catboost  0.8163  0.4815  0.3522     0.421
# lightgbm  0.8147  0.5445  0.3784     0.425
# et        0.7991  0.4877  0.3363     0.449
# xgboost   0.7626  0.6221  0.4465     0.430
# dt        0.6476  0.5629  0.4052     0.447

# %% [markdown]
# ## 모델 : sort, n_select 사용
#
# 기본적으로 compare_models는 sort 매개변수에 정의된 메트릭에 따라 가장 성능이 우수한 단일 모델을 반환합니다. MAE를 기준으로 상위 모델 3개를 반환하도록 코드를 변경해 보겠습니다.

# %%
best_mae_models_top3 = compare_models(sort = 'MAE', n_select = 3)
# Out:
# <style type="text/css">
# #T_25537 th {
#   text-align: left;
# }
row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_25537_row5_col1" class="data row5 col1" >3399.1402</td>
#       <td id="T_25537_row5_col2" class="data row5 col2
# Processing:   0%|          | 0/87 [00:00<?, ?it/s]

# %%
# list of top 3 models by MAE
best_mae_models_top3
# Out:
# [GradientBoostingRegressor(random_state=123),
#  RandomForestRegressor(n_jobs=-1, random_state=123),
#  ExtraTreesRegressor(n_jobs=-1, random_state=123)]

# %% [markdown]
# ## Experiment Logging
#
# - PyCaret은 다양한 유형의 실험 로거와 통합됩니다(기본값 = 'mlflow').
#
# - PyCaret에서 실험 추적을 켜려면 log_experiment 및 experiment_name 매개변수를 설정하면 됩니다.
#
# - 그러면 정의된 로거를 기반으로 모든 메트릭, 하이퍼파라미터 및 아티팩트를 자동으로 추적합니다.

# %%
# from pycaret.regression import *
# s = setup(data, target = 'charges', log_experiment='mlflow', experiment_name='insurance_experiment')

# %%
# compare models
# best = compare_models()

# %%
# start mlflow server on localhost:5000
# !mlflow ui

# %% [markdown]
# ## Create Model
#
# - create_model 함수는 교차 검증을 사용하여 주어진 추정기의 성능을 훈련하고 평가합니다.
# - 이 함수의 출력은 배수별 CV 점수가 포함된 점수 그리드입니다.
# - CV 중에 평가된 지표는 get_metrics 함수를 사용하여 액세스할 수 있습니다.
# - 사용자 지정 지표는 add_metric 및 remove_metric 함수를 사용하여 추가하거나 제거할 수 있습니다.
# - 사용 가능한 모든 모델은 models 함수를 사용하여 액세스할 수 있습니다.

# %%
# check all the available models
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# xgboost           Extreme Gradient Boosting
# lightgbm    Light Gradient Boosting Machine
# catboost                 CatBoost Regressor
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# xgboost                        xgboost.sklearn.XGBRegressor   True
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# catboost                    catboost.core.CatBoostRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %%
# train linear regression with default fold=10
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_a0cab_row10_col0, #T_a0cab_row10_col1, #T_a0cab_row10_col2, #T_a0cab_row10_col3, #T_a0cab_row10_col4, #T_a0cab_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a0cab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0cab_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a0cab_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a0cab_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a0cab_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a0cab_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a0cab_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0cab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0cab_row0_col0" class="data row0 col0" >4207.6462</td>
#       <td id="T_a0cab_row0_col1" class="data row0 col1" >33536119.3129</td>
#       <td id="T_a0cab_row0_col2" class="data row0 col2" >5791.0378</td>
#       <td id="T_a0cab_row0_col3" class="data row0 col3" >0.7997</td>
#       <td id="T_a0cab_row0_col4" class="data row0 col4" >0.4918</td>
#       <td id="T_a0cab_row0_col5" class="data row0 col5" >0.4287</td>
#     </tr>
#     <tr>
#       <th id="T_a0cab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0cab_row1_col0" class="data row1 col0" >4569.3796</td>
#       <td id="T_a0cab_row1_col1" class="data row1 col1" >43872427.6511</td>
#       <td id="T_a0cab_row1_col2" class="data row1 col2" >6623.6265</td>
#       <td id="T_a0cab_row1_col3" class="data row1 col3" >0.7449</td>
#       <td id="T_a0cab_row1_col4" class="data row1 col4" >0.5390</td>
#       <td id="T_a0cab_row1_col5" class="data row1 col5" >0.4359</td>
#     </tr>
#     <tr>
#       <th id="T_a0cab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a0cab_row2_col0" class="data row2 col0" >3908.9421</td>
#       <td id="T_a0cab_row2_col1" class="data row2 col1" >32421521.6791</td>
#       <td id="T_a0cab_row2_col2" class="data row2 col2" >5693.9900</td>
#       <td id="T_a0cab_row2_col3" class="data row2 col3" >0.5895</td>
#       <td id="T_a0cab_row2_col4" class="data row2 col4" >0.9861</td>
#       <td id="T_a0cab_row2_col5" class="data row2 col5" >0.4461</td>
#     </tr>
#     <tr>
#       <th id="T_a0cab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a0cab_row3_col0" class="data row3 col0" >3749.2132</td>
#       <td id="T_a0cab_row3_col1" class="data row3 col1" >26900508.0771</td>
#       <td id="T_a0cab_row3_col2" class="data row3 col2" >5186.5700</td>
#       <td id="T_a0cab_row3_col3" class="data row3 col3" >0.7754</td>
#       <td id="T_a0cab_row3_col4" class="data row3 col4" >0.4919</td>
#       <td id="T_a0cab_row3_col5" class="data row3 col5" >0.5267</td>
#     </tr>
#     <tr>
#       <th id="T_a0cab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a
td>
#     </tr>
#     <tr>
#       <th id="T_ebbfc_level1_row6" class="row_heading level1 row6" >6</th>
#       <td id="T_ebbfc_row6_col0" class="data row6 col0" >4270.7252</td>
#       <td id="T_ebbfc_row6_col1" class="data row6 col1" >37519519.0498</td>
#       <td id="T_ebbfc_row6_col2" class="data row6 col2" >6125.3179</td>
#       <td id="T_ebbfc_row6_col3" class="data row6 col3" >0.7469</td>
#       <td id="T_ebbfc_row6_col4" class="data row6 col4" >0.5509</td>
#       <td id="T_ebbfc_row6_col5" class="data row6 col5" >0.4341</td>
#     </tr>
#     <tr>
#       <th id="T_ebbfc_level1_row7" class="row_heading level1 row7" >7</th>
#       <td id="T_ebbfc_row7_col0" class="data row7 col0" >4162.9018</td>
#       <td id="T_ebbfc_row7_col1" class="data row7 col1" >36837456.8885</td>
#       <td id="T_ebbfc_row7_col2" class="data row7 col2" >6069.3869</td>
#       <td id="T_ebbfc_row7_col3" class="data row7 col3" >0.7443</td>
#       <td id="T_ebbfc_row7_col4" class="data row7 col4" >0.6292</td>
#       <td id="T_ebbfc_row7_col5" class="data row7 col5" >0.4251</td>
#     </tr>
#     <tr>
#       <th id="T_ebbfc_level1_row8" class="row_heading level1 row8" >8</th>
#       <td id="T_ebbfc_row8_col0" class="data row8 col0" >4232.6908</td>
#       <td id="T_ebbfc_row8_col1" class="data row8 col1" >37501473.1045</td>
#       <td id="T_ebbfc_row8_col2" class="data row8 col2" >6123.8446</td>
#       <td id="T_ebbfc_row8_col3" class="data row8 col3" >0.7455</td>
#       <td id="T_ebbfc_row8_col4" class="data row8 col4" >0.5779</td>
#       <td id="T_ebbfc_row8_col5" class="data row8 col5" >0.4328</td>
#     </tr>
#     <tr>
#       <th id="T_ebbfc_level1_row9" class="row_heading level1 row9" >9</th>
#       <td id="T_ebbfc_row9_col0" class="data row9 col0" >4240.5223</td>
#       <td id="T_ebbfc_row9_col1" class="data row9 col1" >37297017.2603</td>
#       <td id="T_ebbfc_row9_col2" class="data row9 col2" >6107.1284</td>
#       <td id="T_ebbfc_row9_col3" class="data row9 col3" >0.7468</td>
#       <td id="T_ebbfc_row9_col4" class="data row9 col4" >0.6021</td>
#       <td id="T_ebbfc_row9_col5" class="data row9 col5" >0.4384</td>
#     </tr>
#     <tr>
#       <th id="T_ebbfc_level0_row10" class="row_heading level0 row10" rowspan="10">CV-Val</th>
#       <th id="T_ebbfc_level1_row10" class="row_heading level1 row10" >0</th>
#       <td id="T_ebbfc_row10_col0" class="data row10 col0" >4207.6462</td>
#       <td id="T_ebbfc_row10_col1" class="data row10 col1" >33536119.3129</td>
#       <td id="T_ebbfc_row10_col2" class="data row10 col2" >5791.0378</td>
#       <td id="T_ebbfc_row10_col3" class="data row10 col3" >0.7997</td>
#       <td id="T_ebbfc_row10_col4" class="data row10 col4" >0.4918</td>
#       <td id="T_ebbfc_row10_col5" class="data row10 col5" >0.4287</td>
#     </tr>
#     <tr>
#       <th id="T_ebbfc_level1_row11" class="row_heading level1 row11" >1</th>
#       <td id="T_ebbfc_row11_col0" class="data row11 col0" >4569.3796</td>
#       <td id="T_ebbfc_row11_col1" class="data row11 col1" >43872427.6511</td>
#       <td id="T_ebbfc_row11_col2" class="data row11 col2" >6623.6265</td>
#       <td id="T_ebbfc_row11_col3" class="data row11 col3" >0.7449</td>
#       <td id="T_ebbfc_row11_col4" class="data row11 col4" >0.5390</td>
#       <td id="T_ebbfc_row11_col5" class="data row11 col5" >0.4359</td>
#     </tr>
#     <tr>
#       <th id="T_ebbfc_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_ebbfc_row12_col0" class="data row12 col0" >3908.9421</td>
#       <td id="T_ebbfc_row12_col1" class="data row12 col1" >32421521.6791</td>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# LinearRegression(n_jobs=-1)

# %% [markdown]
# ### Some other parameters that you might find very useful in create_model are:
#
# - cross_validation
# - engine
# - fit_kwargs
# - groups

# %% [markdown]
# ## Tune Model
